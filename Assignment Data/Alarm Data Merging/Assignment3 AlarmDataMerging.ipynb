# %%
import pandas as pd
import numpy as np

# %%
ADC = pd.read_csv('AlarmDataCustomer.csv')
ADL = pd.read_csv('AlarmDataLocation.csv')

# %%
AD
# Out:
#                              AlarmServiceName  ExternalID  \
# 0                             Pull Cord Alarm      5283.0
# 1                             Pull Cord Alarm      5283.0
# 2                             Pull Cord Alarm      5283.0
# 3                             Pull Cord Alarm      5283.0
# 4                             Pull Cord Alarm      5283.0
# ...                                       ...         ...
# 39280  Alarm - Physical Response Not Required      8866.0
# 39281  Alarm - Physical Response Not Required      8866.0
# 39282  Alarm - Physical Response Not Required      8866.0
# 39283                                   Alarm      8866.0
# 39284                                   Alarm      8949.0
#
#                     Building       City  \
# 0        Broom Main Building   Stirling
# 1        Broom Main Building   Stirling
# 2        Broom Main Building   Stirling
# 3        Broom Main Building   Stirling
# 4        Broom Main Building   Stirling
# ...

# %%
ADL['ExternalID'] = ADL['ExternalID'].astype('int16').astype('str')
ADL_cl = ADL
ADL_cl
ADL_cl = ADL_cl.rename(columns={'AlarmServiceName':'ServiceName'})
#ADL_cl = ADL_cl[['ExternalID','ServiceName','Building','City','CareServiceType','Geog','HouseType','StartTime']]
ADL_cl['StartTime'] = pd.to_datetime(ADL_cl['StartTime'], infer_datetime_format=True)

# %%
ADL_cl.head()
ADL_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39285 entries, 0 to 39284
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ServiceName      39285 non-null  object
#  1   ExternalID       39285 non-null  object
#  2   Building         39285 non-null  object
#  3   City             39285 non-null  object
#  4   CareServiceType  39285 non-null  object
#  5   Geog             39285 non-null  object
#  6   HouseType        39285 non-null  object
#  7   StartTime        39285 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(7)
# memory usage: 2.4+ MB

# %%
ADC.head()
ADC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28814 entries, 0 to 28813
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ExternalID           28814 non-null  int64
#  1   ServiceName          28814 non-null  object
#  2   StartTime            28814 non-null  object
#  3   Status               28814 non-null  object
#  4   MonthYear            28814 non-null  object
#  5   DayMonthYear         28814 non-null  object
#  6   Gender               28814 non-null  object
#  7   DateOfBirth          28814 non-null  object
#  8   Age                  28814 non-null  int64
#  9   DisablingConditions  28814 non-null  object
#  10  AgeGroup             28814 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 2.4+ MB

# %%
ADC['ExternalID'] = ADC['ExternalID'].astype('str')
ADC['StartTime'] = pd.to_datetime(ADC['StartTime'], infer_datetime_format=True)
ADC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28814 entries, 0 to 28813
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ExternalID           28814 non-null  object
#  1   ServiceName          28814 non-null  object
#  2   StartTime            28814 non-null  datetime64[ns]
#  3   Status               28814 non-null  object
#  4   MonthYear            28814 non-null  object
#  5   DayMonthYear         28814 non-null  object
#  6   Gender               28814 non-null  object
#  7   DateOfBirth          28814 non-null  object
#  8   Age                  28814 non-null  int64
#  9   DisablingConditions  28814 non-null  object
#  10  AgeGroup             28814 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 2.4+ MB

# %%
ADM = pd.merge(ADC, ADL_cl, how='inner', on=['ExternalID', 'ServiceName', 'StartTime'])

# %%
ADM
# Out:
#       ExternalID      ServiceName           StartTime     Status MonthYear  \
# 0           5283  Pull Cord Alarm 2018-10-29 00:15:00  completed   2018-10
# 1           5977            Alarm 2018-10-29 00:44:00  completed   2018-10
# 2           5977            Alarm 2018-10-29 00:44:00  completed   2018-10
# 3           5977            Alarm 2018-10-29 00:44:00  completed   2018-10
# 4           5977            Alarm 2018-10-29 00:44:00  completed   2018-10
# ...          ...              ...                 ...        ...       ...
# 15536       8653            Alarm 2020-09-30 22:03:00  completed   2020-09
# 15537       5306            Alarm 2020-09-30 22:29:00  completed   2020-09
# 15538       5306            Alarm 2020-09-30 22:43:00  completed   2020-09
# 15539       8639            Alarm 2020-09-30 22:57:00  completed   2020-09
# 15540       8806            Alarm 2020-09-30 23:59:00  completed   2020-09
#
# ...

# %%
ADM.to_csv('AlarmData.csv',index=False,sep=',')
